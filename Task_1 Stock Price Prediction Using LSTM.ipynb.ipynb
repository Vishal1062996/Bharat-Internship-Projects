# %%
#importing libraries to be used
import numpy as np # for linear algebra
import pandas as pd # data preprocessing
import matplotlib.pyplot as plt # data visualization library
import seaborn as sns # data visualization library
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore') # ignore warnings 

from sklearn.preprocessing import MinMaxScaler # for normalization
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Bidirectional

# %%
df = pd.read_csv(r"C:\Users\Msi\OneDrive\Desktop\data\GOOG.csv") # data_importing
df.head(10) # fetching first 10 rows of dataset
# Out:
#   symbol                       date   close    high       low    open  \
# 0   GOOG  2016-06-14 00:00:00+00:00  718.27  722.47  713.1200  716.48
# 1   GOOG  2016-06-15 00:00:00+00:00  718.92  722.98  717.3100  719.00
# 2   GOOG  2016-06-16 00:00:00+00:00  710.36  716.65  703.2600  714.91
# 3   GOOG  2016-06-17 00:00:00+00:00  691.72  708.82  688.4515  708.65
# 4   GOOG  2016-06-20 00:00:00+00:00  693.71  702.48  693.4100  698.77
# 5   GOOG  2016-06-21 00:00:00+00:00  695.94  702.77  692.0100  698.40
# 6   GOOG  2016-06-22 00:00:00+00:00  697.46  700.86  693.0819  699.06
# 7   GOOG  2016-06-23 00:00:00+00:00  701.87  701.95  687.0000  697.45
# 8   GOOG  2016-06-24 00:00:00+00:00  675.22  689.40  673.4500  675.17
# 9   GOOG  2016-06-27 00:00:00+00:00  668.26  672.30  663.2840  671.00
#
#     volume  adjClose  adjHigh    adjLow  adjOpen  adjVolume  divCash  \
# 0  1306065    718.27   722.47  713.1200   716.48    1306065      0.0
# 1  1214517    718.92   722.98  717.3100   719.00    1214517      0.0
# 2  1982471    710.36   716.65  703.2600   714.91    1982471      0.0
# 3  3402357    691.72   708.82  688.4515   708.65    3402357      0.0
# 4  2082538    693.71   702.48  693.4100   698.77    2082538      0.0
# 5  1465634    695.94   702.77  692.0100   698.40    1465634      0.0
# 6  1184318    697.46   700.86  693.0819   699.06    1184318      0.0
# 7  2171415    701.87   701.95  687.0000   697.45    2171415      0.0
# 8  4449022    675.22   689.40  673.4500   675.17    4449022      0.0
# 9  2641085    668.26   672.30  663.2840   671.00    2641085      0.0
#
#    splitFactor
# 0          1.0
# 1          1.0
# 2          1.0
# 3          1.0
# 4          1.0
# 5          1.0
# 6          1.0
# 7          1.0
# 8          1.0
# 9          1.0

# %%
df.shape
# Out:
# (1258, 14)

# %%
df.describe()
# Out:
#              close         high          low         open        volume  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1.258000e+03
# mean   1216.317067  1227.430934  1204.176430  1215.260779  1.601590e+06
# std     383.333358   387.570872   378.777094   382.446995  6.960172e+05
# min     668.260000   672.300000   663.284000   671.000000  3.467530e+05
# 25%     960.802500   968.757500   952.182500   959.005000  1.173522e+06
# 50%    1132.460000  1143.935000  1117.915000  1131.150000  1.412588e+06
# 75%    1360.595000  1374.345000  1348.557500  1361.075000  1.812156e+06
# max    2521.600000  2526.990000  2498.290000  2524.920000  6.207027e+06
#
#           adjClose      adjHigh       adjLow      adjOpen     adjVolume  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1.258000e+03
# mean   1216.317067  1227.430936  1204.176436  1215.260779  1.601590e+06
# std     383.333358   387.570873   378.777099   382.446995  6.960172e+05
# min     668.260000   672.300000   663.284000   671.000000  3.467530e+05
# 25%     960.802500   968.757500   952.182500   959.005000  1.173522e+06
# 50%    1132.460000  1143.935000  1117.915000  1131.150000  1.412588e+06
# 75%    1360.595000  1374.345000  1348.557500  1361.075000  1.812156e+06
# max    2521.600000  2526.990000  2498.290000  2524.920000  6.207027e+06
#
#        divCash  splitFactor
# count   1258.0       1258.0
# mean       0.0          1.0
# std        0.0          0.0
# min        0.0          1.0
# 25%        0.0          1.0
# 50%        0.0          1.0
# 75%        0.0          1.0
# max        0.0          1.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   symbol       1258 non-null   object
#  1   date         1258 non-null   object
#  2   close        1258 non-null   float64
#  3   high         1258 non-null   float64
#  4   low          1258 non-null   float64
#  5   open         1258 non-null   float64
#  6   volume       1258 non-null   int64
#  7   adjClose     1258 non-null   float64
#  8   adjHigh      1258 non-null   float64
#  9   adjLow       1258 non-null   float64
#  10  adjOpen      1258 non-null   float64
#  11  adjVolume    1258 non-null   int64
#  12  divCash      1258 non-null   float64
#  13  splitFactor  1258 non-null   float64
# dtypes: float64(10), int64(2), object(2)
# memory usage: 137.7+ KB

# %%
df.isnull().sum()
# Out:
# symbol         0
# date           0
# close          0
# high           0
# low            0
# open           0
# volume         0
# adjClose       0
# adjHigh        0
# adjLow         0
# adjOpen        0
# adjVolume      0
# divCash        0
# splitFactor    0
# dtype: int64

# %%
df = df[['date','open','close']] # Extracting required columns
df['date'] = pd.to_datetime(df['date'].apply(lambda x: x.split()[0])) # converting object dtype of date column to datetime dtype
df.set_index('date',drop=True,inplace=True) # Setting date column as index
df.head(10)
# Out:
#               open   close
# date
# 2016-06-14  716.48  718.27
# 2016-06-15  719.00  718.92
# 2016-06-16  714.91  710.36
# 2016-06-17  708.65  691.72
# 2016-06-20  698.77  693.71
# 2016-06-21  698.40  695.94
# 2016-06-22  699.06  697.46
# 2016-06-23  697.45  701.87
# 2016-06-24  675.17  675.22
# 2016-06-27  671.00  668.26

# %%
fig, ax =plt.subplots(1,2,figsize=(20,7))
ax[0].plot(df['open'],label='Open',color='green')
ax[0].set_xlabel('Date',size=15)
ax[0].set_ylabel('Price',size=15)
ax[0].legend()

ax[1].plot(df['close'],label='Close',color='red')
ax[1].set_xlabel('Date',size=15)
ax[1].set_ylabel('Price',size=15)
ax[1].legend()

fig.show()

# %%
MMS = MinMaxScaler()
df[df.columns] = MMS.fit_transform(df)
df.head(10)
# Out:
#                 open     close
# date
# 2016-06-14  0.024532  0.026984
# 2016-06-15  0.025891  0.027334
# 2016-06-16  0.023685  0.022716
# 2016-06-17  0.020308  0.012658
# 2016-06-20  0.014979  0.013732
# 2016-06-21  0.014779  0.014935
# 2016-06-22  0.015135  0.015755
# 2016-06-23  0.014267  0.018135
# 2016-06-24  0.002249  0.003755
# 2016-06-27  0.000000  0.000000

# %%
training_size = round(len(df) * 0.75) # Selecting 75 % for training and 25 % for testing
training_size
# Out:
# 944

# %%
train_data = df[:training_size]
test_data  = df[training_size:]

train_data.shape, test_data.shape
# Out:
# ((944, 2), (314, 2))

# %%
# Function to create sequence of data for training and testing

def create_sequence(dataset):
  sequences = []
  labels = []

  start_idx = 0

  for stop_idx in range(50,len(dataset)): # Selecting 50 rows at a time
    sequences.append(dataset.iloc[start_idx:stop_idx])
    labels.append(dataset.iloc[stop_idx])
    start_idx += 1
  return (np.array(sequences),np.array(labels))

# %%
train_seq, train_label = create_sequence(train_data) 
test_seq, test_label = create_sequence(test_data)
train_seq.shape, train_label.shape, test_seq.shape, test_label.shape
# Out:
# ((894, 50, 2), (894, 2), (264, 50, 2), (264, 2))

# %%
# imported Sequential from keras.models 
model = Sequential()
# importing Dense, Dropout, LSTM, Bidirectional from keras.layers 
model.add(LSTM(units=50, return_sequences=True, input_shape = (train_seq.shape[1], train_seq.shape[2])))

model.add(Dropout(0.1)) 
model.add(LSTM(units=50))

model.add(Dense(2))

model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 50, 50)            10600
#
#  dropout (Dropout)           (None, 50, 50)            0
#
#  lstm_1 (LSTM)               (None, 50)                20200
#
#  dense (Dense)               (None, 2)                 102
#
# =================================================================
# Total params: 30902 (120.71 KB)
# Trainable params: 30902 (120.71 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# fitting the model by iterating the dataset over 100 times(100 epochs)
model.fit(train_seq, train_label, epochs=100,validation_data=(test_seq, test_label), verbose=1)
# Out:
# Epoch 1/100
# 28/28 [==============================] - 11s 118ms/step - loss: 0.0046 - mean_absolute_error: 0.0474 - val_loss: 0.0099 - val_mean_absolute_error: 0.0810
# Epoch 2/100
# 28/28 [==============================] - 2s 56ms/step - loss: 6.2490e-04 - mean_absolute_error: 0.0193 - val_loss: 0.0029 - val_mean_absolute_error: 0.0407
# Epoch 3/100
# 28/28 [==============================] - 2s 56ms/step - loss: 4.0947e-04 - mean_absolute_error: 0.0150 - val_loss: 0.0025 - val_mean_absolute_error: 0.0383
# Epoch 4/100
# 28/28 [==============================] - 2s 57ms/step - loss: 4.1677e-04 - mean_absolute_error: 0.0145 - val_loss: 0.0031 - val_mean_absolute_error: 0.0434
# Epoch 5/100
# 28/28 [==============================] - 2s 55ms/step - loss: 4.0387e-04 - mean_absolute_error: 0.0146 - val_loss: 0.0050 - val_mean_absolute_error: 0.0576
# Epoch 6/100
# 28/28 [==============================] - 2s 55ms/step - loss: 4.1091e-04 - mean_absolute_error: 0.0149 - val_loss: 0.0019 - val_mean_absolute_error: 0.0332
# Epoch 7/100
# 28/28 [==============================] - 2s 57ms/step - loss: 4.0725e-04 - mean_absolute_error: 0.0148 - val_loss: 0.0052 - val_mean_absolute_error: 0.0594
# Epoch 8/100
# 28/28 [==============================] - 2s 57ms/step - loss: 4.0208e-04 - mean_absolute_error: 0.0145 - val_loss: 0.0047 - val_mean_absolute_error: 0.0550
# Epoch 9/100
# 28/28 [==============================] - 2s 56ms/step - loss: 3.8169e-04 - mean_absolute_error: 0.0142 - val_loss: 0.0028 - val_mean_absolute_error: 0.0404
# Epoch 10/100
# 28/28 [==============================] - 2s 56ms/step - loss: 3.8461e-04 - mean_absolute_error: 0.0141 - val_loss: 0.0036 - val_mean_absolute_error: 0.0472
# Epoch 11/100
# 28/28 [==============================] - 2s 56ms/step - loss: 3.5649e-04 - mean_absolute_error: 0.0137 - val_loss: 0.0054 - val_mean_absolute_error: 0.0599
# Epoch 12/100
# 28/28 [==============================] - 2s 55ms/step - loss: 3.6039e-04 - mean_absolute_error: 0.0138 - val_loss: 0.0043 - val_mean_absolute_error: 0.0532
# Epoch 13/100
# 28/28 [==============================] - 2s 56ms/step - loss: 3.2052e-04 - mean_absolute_error: 0.0131 - val_loss: 0.0027 - val_mean_absolute_error: 0.0393
# Epoch 14/100
# 28/28 [==============================] - 2s 55ms/step - loss: 3.2151e-04 - mean_absolute_error: 0.0131 - val_loss: 0.0027 - val_mean_absolute_error: 0.0393
# Epoch 15/100
# 28/28 [==============================] - 2s 58ms/step - loss: 3.1096e-04 - mean_absolute_error: 0.0128 - val_loss: 0.0030 - val_mean_absolute_error: 0.0425
# Epoch 16/100
# 28/28 [==============================] - 2s 59ms/step - loss: 2.9698e-04 - mean_absolute_error: 0.0125 - val_loss: 0.0037 - val_mean_absolute_error: 0.0479
# Epoch 17/100
# 28/28 [==============================] - 2s 56ms/step - loss: 2.9448e-04 - mean_absolute_error: 0.0125 - val_loss: 0.0055 - val_mean_absolute_error: 0.0604
# Epoch 18/100
# 28/28 [==============================] - 2s 57ms/step - loss: 3.1724e-04 - mean_absolute_error: 0.0131 - val_loss: 0.0039 - val_mean_absolute_error: 0.0501
# Epoch 19/100
# 28/28 [==============================] - 2s 57ms/step - loss: 2.9950e-04 - mean_absolute_error: 0.0127 - val_loss: 0.0028 - val_mean_absolute_error: 0.0409
# Epoch 20/100
# 28/28 [==============================] - 2s 57ms/step - loss: 2.5639e-04 - mean_absolute_error: 0.0118 - val_loss: 0.0077 - val_mean_absolute_error: 0.0743
# Epoch 21/100
# 28/28 [==============================] - 2s 58ms/step - loss: 3.3720e-04 - mean_absolute_error: 0.0135 - val_loss: 0.0039 - val_mean_absolute_error: 0.0490
# Epoch 22/100
# 28/28 [==============================] - 2s 58ms/step - loss: 2.6777e-04 - mean_absolute_error: 0.0119 - val_loss: 0.0043 - val_mean_absolute_error: 0.0528
# Epoch 23/100
# 28/28 [==============================] - 2s 58ms/step - loss: 2.6735e-04 - mean_absolute_error: 0.0119 - val_loss: 0.0059 - val_mean_absolute_error: 0.0640
# Epoch 24/100
# 28/28 [==============================] - 2s 57ms/step - loss: 2.6723e-04 - mean_absolute_error: 0.0119 - val_loss: 0.0075 - val_mean_absolute_error: 0.0734
# Epoch 25/100
# 28/28 [==============================] - 2s 58ms/step - loss: 2.8332e-04 - mean_absolute_error: 0.0126 - val_loss: 0.0044 - val_mean_absolute_error: 0.0538
# Epoch 26/100
# 28/28 [==============================] - 2s 57ms/step - loss: 2.6847e-04 - mean_absolute_error: 0.0120 - val_loss: 0.0042 - val_mean_absolute_error: 0.0525
# Epoch 27/100
# 28/28 [==============================] - 2s 56ms/step - loss: 2.4732e-04 - mean_absolute_error: 0.0113 - val_loss: 0.0028 - val_mean_absolute_error: 0.0400
# Epoch 28/100
# 28/28 [==============================] - 2s 55ms/step - loss: 2.4246e-04 - mean_absolute_error: 0.0114 - val_loss: 0.0055 - val_mean_absolute_error: 0.0602
# Epoch 29/100
# 28/28 [==============================] - 2s 57ms/step - loss: 2.6937e-04 - mean_absolute_error: 0.0122 - val_loss: 0.0046 - val_mean_absolute_error: 0.0540
# Epoch 30/100
# 28/28 [==============================] - 2s 56ms/step - loss: 2.6197e-04 - mean_absolute_error: 0.0117 - val_loss: 0.0033 - val_mean_absolute_error: 0.0442
# Epoch 31/100
# 28/28 [==============================] - 2s 58ms/step - loss: 2.4873e-04 - mean_absolute_error: 0.0116 - val_loss: 0.0023 - val_mean_absolute_error: 0.0357
# Epoch 32/100
# 28/28 [==============================] - 2s 57ms/step - loss: 2.3675e-04 - mean_absolute_error: 0.0112 - val_loss: 0.0040 - val_mean_absolute_error: 0.0504
# Epoch 33/100
# 28/28 [==============================] - 2s 60ms/step - loss: 2.3126e-04 - mean_absolute_error: 0.0110 - val_loss: 0.0024 - val_mean_absolute_error: 0.0369
# Epoch 34/100
# 28/28 [==============================] - 2s 57ms/step - loss: 2.1955e-04 - mean_absolute_error: 0.0108 - val_loss: 0.0040 - val_mean_absolute_error: 0.0496
# Epoch 35/100
# 28/28 [==============================] - 2s 57ms/step - loss: 2.1906e-04 - mean_absolute_error: 0.0109 - val_loss: 0.0019 - val_mean_absolute_error: 0.0319
# Epoch 36/100
# 28/28 [==============================] - 2s 55ms/step - loss: 2.3883e-04 - mean_absolute_error: 0.0115 - val_loss: 0.0028 - val_mean_absolute_error: 0.0391
# Epoch 37/100
# 28/28 [==============================] - 2s 57ms/step - loss: 2.2895e-04 - mean_absolute_error: 0.0108 - val_loss: 0.0053 - val_mean_absolute_error: 0.0603
# Epoch 38/100
# 28/28 [==============================] - 2s 57ms/step - loss: 2.1392e-04 - mean_absolute_error: 0.0106 - val_loss: 0.0025 - val_mean_absolute_error: 0.0375
# Epoch 39/100
# 28/28 [==============================] - 2s 55ms/step - loss: 2.0370e-04 - mean_absolute_error: 0.0104 - val_loss: 0.0019 - val_mean_absolute_error: 0.0326
# Epoch 40/100
# 28/28 [==============================] - 2s 56ms/step - loss: 1.9144e-04 - mean_absolute_error: 0.0101 - val_loss: 0.0019 - val_mean_absolute_error: 0.0322
# Epoch 41/100
# 28/28 [==============================] - 2s 56ms/step - loss: 2.2600e-04 - mean_absolute_error: 0.0109 - val_loss: 0.0022 - val_mean_absolute_error: 0.0351
# Epoch 42/100
# 28/28 [==============================] - 2s 57ms/step - loss: 1.9730e-04 - mean_absolute_error: 0.0101 - val_loss: 0.0028 - val_mean_absolute_error: 0.0416
# Epoch 43/100
# 28/28 [==============================] - 2s 56ms/step - loss: 1.9180e-04 - mean_absolute_error: 0.0100 - val_loss: 0.0022 - val_mean_absolute_error: 0.0350
# Epoch 44/100
# 28/28 [==============================] - 2s 56ms/step - loss: 1.9855e-04 - mean_absolute_error: 0.0105 - val_loss: 0.0025 - val_mean_absolute_error: 0.0377
# Epoch 45/100
# 28/28 [==============================] - 2s 57ms/step - loss: 1.9797e-04 - mean_absolute_error: 0.0103 - val_loss: 0.0020 - val_mean_absolute_error: 0.0333
# Epoch 46/100
# 28/28 [==============================] - 2s 56ms/step - loss: 1.9743e-04 - mean_absolute_error: 0.0103 - val_loss: 0.0027 - val_mean_absolute_error: 0.0396
# Epoch 47/100
# 28/28 [==============================] - 2s 56ms/step - loss: 1.8621e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0033 - val_mean_absolute_error: 0.0439
# Epoch 48/100
# 28/28 [==============================] - 2s 57ms/step - loss: 2.0909e-04 - mean_absolute_error: 0.0105 - val_loss: 0.0033 - val_mean_absolute_error: 0.0441
# Epoch 49/100
# 28/28 [==============================] - 2s 56ms/step - loss: 1.9121e-04 - mean_absolute_error: 0.0102 - val_loss: 0.0010 - val_mean_absolute_error: 0.0233
# Epoch 50/100
# 28/28 [==============================] - 2s 57ms/step - loss: 1.8597e-04 - mean_absolute_error: 0.0099 - val_loss: 0.0025 - val_mean_absolute_error: 0.0377
# Epoch 51/100
# 28/28 [==============================] - 2s 56ms/step - loss: 1.6955e-04 - mean_absolute_error: 0.0093 - val_loss: 0.0025 - val_mean_absolute_error: 0.0378
# Epoch 52/100
# 28/28 [==============================] - 2s 57ms/step - loss: 1.7594e-04 - mean_absolute_error: 0.0094 - val_loss: 0.0021 - val_mean_absolute_error: 0.0339
# Epoch 53/100
# 28/28 [==============================] - 2s 55ms/step - loss: 1.6794e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0018 - val_mean_absolute_error: 0.0305
# Epoch 54/100
# 28/28 [==============================] - 2s 57ms/step - loss: 1.6527e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0024 - val_mean_absolute_error: 0.0368
# Epoch 55/100
# 28/28 [==============================] - 2s 57ms/step - loss: 1.6814e-04 - mean_absolute_error: 0.0095 - val_loss: 0.0013 - val_mean_absolute_error: 0.0263
# Epoch 56/100
# 28/28 [==============================] - 2s 57ms/step - loss: 1.6033e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0018 - val_mean_absolute_error: 0.0315
# Epoch 57/100
# 28/28 [==============================] - 2s 59ms/step - loss: 1.6170e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0030 - val_mean_absolute_error: 0.0445
# Epoch 58/100
# 28/28 [==============================] - 2s 56ms/step - loss: 1.7392e-04 - mean_absolute_error: 0.0097 - val_loss: 0.0031 - val_mean_absolute_error: 0.0439
# Epoch 59/100
# 28/28 [==============================] - 2s 58ms/step - loss: 1.5042e-04 - mean_absolute_error: 0.0089 - val_loss: 0.0018 - val_mean_absolute_error: 0.0327
# Epoch 60/100
# 28/28 [==============================] - 2s 57ms/step - loss: 1.5297e-04 - mean_absolute_error: 0.0089 - val_loss: 0.0017 - val_mean_absolute_error: 0.0318
# Epoch 61/100
# 28/28 [==============================] - 2s 55ms/step - loss: 1.6734e-04 - mean_absolute_error: 0.0094 - val_loss: 9.2958e-04 - val_mean_absolute_error: 0.0221
# Epoch 62/100
# 28/28 [==============================] - 2s 57ms/step - loss: 1.6644e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0013 - val_mean_absolute_error: 0.0269
# Epoch 63/100
# 28/28 [==============================] - 2s 56ms/step - loss: 1.5413e-04 - mean_absolute_error: 0.0090 - val_loss: 5.6882e-04 - val_mean_absolute_error: 0.0176
# Epoch 64/100
# 28/28 [==============================] - 2s 55ms/step - loss: 1.5367e-04 - mean_absolute_error: 0.0090 - val_loss: 0.0013 - val_mean_absolute_error: 0.0272
# Epoch 65/100
# 28/28 [==============================] - 2s 55ms/step - loss: 1.4591e-04 - mean_absolute_error: 0.0087 - val_loss: 7.5655e-04 - val_mean_absolute_error: 0.0199
# Epoch 66/100
# 28/28 [==============================] - 2s 57ms/step - loss: 1.6760e-04 - mean_absolute_error: 0.0093 - val_loss: 0.0017 - val_mean_absolute_error: 0.0317
# Epoch 67/100
# 28/28 [==============================] - 2s 55ms/step - loss: 1.4330e-04 - mean_absolute_error: 0.0085 - val_loss: 7.0773e-04 - val_mean_absolute_error: 0.0193
# Epoch 68/100
# 28/28 [==============================] - 2s 56ms/step - loss: 1.6713e-04 - mean_absolute_error: 0.0094 - val_loss: 0.0025 - val_mean_absolute_error: 0.0410
# Epoch 69/100
# 28/28 [==============================] - 2s 55ms/step - loss: 1.4968e-04 - mean_absolute_error: 0.0088 - val_loss: 7.7317e-04 - val_mean_absolute_error: 0.0202
# Epoch 70/100
# 28/28 [==============================] - 2s 56ms/step - loss: 1.6018e-04 - mean_absolute_error: 0.0092 - val_loss: 6.6144e-04 - val_mean_absolute_error: 0.0187
# Epoch 71/100
# 28/28 [==============================] - 2s 57ms/step - loss: 1.4415e-04 - mean_absolute_error: 0.0086 - val_loss: 0.0018 - val_mean_absolute_error: 0.0341
# Epoch 72/100
# 28/28 [==============================] - 2s 57ms/step - loss: 1.3338e-04 - mean_absolute_error: 0.0083 - val_loss: 0.0018 - val_mean_absolute_error: 0.0339
# Epoch 73/100
# 28/28 [==============================] - 2s 56ms/step - loss: 1.4148e-04 - mean_absolute_error: 0.0085 - val_loss: 0.0010 - val_mean_absolute_error: 0.0236
# Epoch 74/100
# 28/28 [==============================] - 2s 55ms/step - loss: 1.3015e-04 - mean_absolute_error: 0.0082 - val_loss: 0.0020 - val_mean_absolute_error: 0.0357
# Epoch 75/100
# 28/28 [==============================] - 2s 55ms/step - loss: 1.3489e-04 - mean_absolute_error: 0.0083 - val_loss: 7.9246e-04 - val_mean_absolute_error: 0.0212
# Epoch 76/100
# 28/28 [==============================] - 2s 57ms/step - loss: 1.3154e-04 - mean_absolute_error: 0.0081 - val_loss: 5.3019e-04 - val_mean_absolute_error: 0.0167
# Epoch 77/100
# 28/28 [==============================] - 2s 57ms/step - loss: 1.3789e-04 - mean_absolute_error: 0.0086 - val_loss: 0.0017 - val_mean_absolute_error: 0.0333
# Epoch 78/100
# 28/28 [==============================] - 2s 56ms/step - loss: 1.3374e-04 - mean_absolute_error: 0.0083 - val_loss: 6.0865e-04 - val_mean_absolute_error: 0.0180
# Epoch 79/100
# 28/28 [==============================] - 2s 56ms/step - loss: 1.3444e-04 - mean_absolute_error: 0.0083 - val_loss: 0.0011 - val_mean_absolute_error: 0.0248
# Epoch 80/100
# 28/28 [==============================] - 2s 66ms/step - loss: 1.3363e-04 - mean_absolute_error: 0.0082 - val_loss: 5.9394e-04 - val_mean_absolute_error: 0.0180
# Epoch 81/100
# 28/28 [==============================] - 2s 56ms/step - loss: 1.2909e-04 - mean_absolute_error: 0.0081 - val_loss: 7.6460e-04 - val_mean_absolute_error: 0.0205
# Epoch 82/100
# 28/28 [==============================] - 2s 57ms/step - loss: 1.1959e-04 - mean_absolute_error: 0.0080 - val_loss: 6.2893e-04 - val_mean_absolute_error: 0.0182
# Epoch 83/100
# 28/28 [==============================] - 2s 57ms/step - loss: 1.1828e-04 - mean_absolute_error: 0.0078 - val_loss: 6.6846e-04 - val_mean_absolute_error: 0.0188
# Epoch 84/100
# 28/28 [==============================] - 2s 56ms/step - loss: 1.2269e-04 - mean_absolute_error: 0.0079 - val_loss: 0.0014 - val_mean_absolute_error: 0.0295
# Epoch 85/100
# 28/28 [==============================] - 2s 57ms/step - loss: 1.2318e-04 - mean_absolute_error: 0.0079 - val_loss: 6.6687e-04 - val_mean_absolute_error: 0.0187
# Epoch 86/100
# 28/28 [==============================] - 2s 56ms/step - loss: 1.1637e-04 - mean_absolute_error: 0.0077 - val_loss: 0.0020 - val_mean_absolute_error: 0.0368
# Epoch 87/100
# 28/28 [==============================] - 2s 56ms/step - loss: 1.2505e-04 - mean_absolute_error: 0.0081 - val_loss: 8.4343e-04 - val_mean_absolute_error: 0.0219
# Epoch 88/100
# 28/28 [==============================] - 2s 56ms/step - loss: 1.1215e-04 - mean_absolute_error: 0.0073 - val_loss: 6.8618e-04 - val_mean_absolute_error: 0.0201
# Epoch 89/100
# 28/28 [==============================] - 2s 56ms/step - loss: 1.1399e-04 - mean_absolute_error: 0.0076 - val_loss: 9.3756e-04 - val_mean_absolute_error: 0.0247
# Epoch 90/100
# 28/28 [==============================] - 2s 56ms/step - loss: 1.3902e-04 - mean_absolute_error: 0.0087 - val_loss: 9.0380e-04 - val_mean_absolute_error: 0.0228
# Epoch 91/100
# 28/28 [==============================] - 2s 55ms/step - loss: 1.1920e-04 - mean_absolute_error: 0.0078 - val_loss: 5.8997e-04 - val_mean_absolute_error: 0.0176
# Epoch 92/100
# 28/28 [==============================] - 2s 55ms/step - loss: 1.1516e-04 - mean_absolute_error: 0.0077 - val_loss: 5.7936e-04 - val_mean_absolute_error: 0.0177
# Epoch 93/100
# 28/28 [==============================] - 2s 56ms/step - loss: 1.0567e-04 - mean_absolute_error: 0.0074 - val_loss: 5.7654e-04 - val_mean_absolute_error: 0.0172
# Epoch 94/100
# 28/28 [==============================] - 2s 56ms/step - loss: 1.0883e-04 - mean_absolute_error: 0.0073 - val_loss: 0.0011 - val_mean_absolute_error: 0.0247
# Epoch 95/100
# 28/28 [==============================] - 2s 55ms/step - loss: 1.1174e-04 - mean_absolute_error: 0.0075 - val_loss: 6.3718e-04 - val_mean_absolute_error: 0.0190
# Epoch 96/100
# 28/28 [==============================] - 2s 57ms/step - loss: 1.1821e-04 - mean_absolute_error: 0.0079 - val_loss: 5.1518e-04 - val_mean_absolute_error: 0.0166
# Epoch 97/100
# 28/28 [==============================] - 2s 58ms/step - loss: 1.0771e-04 - mean_absolute_error: 0.0074 - val_loss: 4.8665e-04 - val_mean_absolute_error: 0.0159
# Epoch 98/100
# 28/28 [==============================] - 2s 57ms/step - loss: 1.0637e-04 - mean_absolute_error: 0.0073 - val_loss: 0.0018 - val_mean_absolute_error: 0.0348
# Epoch 99/100
# 28/28 [==============================] - 2s 56ms/step - loss: 1.0588e-04 - mean_absolute_error: 0.0072 - val_loss: 6.2447e-04 - val_mean_absolute_error: 0.0187
# Epoch 100/100
# 28/28 [==============================] - 2s 58ms/step - loss: 1.0318e-04 - mean_absolute_error: 0.0071 - val_loss: 0.0012 - val_mean_absolute_error: 0.0277

# %%
# predicting the values after running the model
test_predicted = model.predict(test_seq)
test_predicted[:5]
# Out:
# 9/9 [==============================] - 2s 20ms/step
# array([[0.39538172, 0.39986417],
#        [0.395005  , 0.39943606],
#        [0.39100444, 0.39548892],
#        [0.3953729 , 0.39941466],
#        [0.39927363, 0.4033678 ]], dtype=float32)

# %%
# Inversing normalization/scaling on predicted data 
test_inverse_predicted = MMS.inverse_transform(test_predicted)
test_inverse_predicted[:5]
# Out:
# array([[1404.006 , 1409.3442],
#        [1403.3076, 1408.5509],
#        [1395.891 , 1401.2355],
#        [1403.9896, 1408.5112],
#        [1411.2214, 1415.8376]], dtype=float32)

# %%
# Merging actual and predicted data for better visualization
df_merge = pd.concat([df.iloc[-264:].copy(),
                          pd.DataFrame(test_inverse_predicted,columns=['open_predicted','close_predicted'],
                                       index=df.iloc[-264:].index)], axis=1)

# %%
# Inversing normalization/scaling 
df_merge[['open','close']] = MMS.inverse_transform(df_merge[['open','close']])
df_merge.head()
# Out:
#                open    close  open_predicted  close_predicted
# date
# 2020-05-27  1417.25  1417.84     1404.005981      1409.344238
# 2020-05-28  1396.86  1416.73     1403.307617      1408.550903
# 2020-05-29  1416.94  1428.92     1395.890991      1401.235474
# 2020-06-01  1418.39  1431.82     1403.989624      1408.511230
# 2020-06-02  1430.55  1439.22     1411.221436      1415.837646

# %%
# plotting the actual open and predicted open prices on date index
df_merge[['open','open_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for open price',size=15)
plt.show()

# %%
# plotting the actual close and predicted close prices on date index 
df_merge[['close','close_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for close price',size=15)
plt.show()

# %%
df_new = pd.DataFrame(columns=df_merge.columns,
                        index=pd.date_range(start=df_merge.index[-1], periods=11, freq='D'))
df_merge = pd.concat([df_merge, df_new])

df_merge['2021-06-09':'2021-06-16']
# Out:
#                open    close  open_predicted  close_predicted
# 2021-06-09  2499.50  2491.40     2383.302979      2381.267090
# 2021-06-10  2494.01  2521.60     2384.280273      2382.426025
# 2021-06-11  2524.92  2513.93     2400.028076      2396.044434
# 2021-06-11      NaN      NaN             NaN              NaN
# 2021-06-12      NaN      NaN             NaN              NaN
# 2021-06-13      NaN      NaN             NaN              NaN
# 2021-06-14      NaN      NaN             NaN              NaN
# 2021-06-15      NaN      NaN             NaN              NaN
# 2021-06-16      NaN      NaN             NaN              NaN

# %%
# creating a DataFrame and filling values of open and close column
upcoming_prediction = pd.DataFrame(columns=['open','close'],index=df_merge.index)
upcoming_prediction.index=pd.to_datetime(upcoming_prediction.index)

# %%
curr_seq = test_seq[-1:]

for i in range(-10,0):
  up_pred = model.predict(curr_seq)
  upcoming_prediction.iloc[i] = up_pred
  curr_seq = np.append(curr_seq[0][1:],up_pred,axis=0)
  curr_seq = curr_seq.reshape(test_seq[-1:].shape)
# Out:
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 46ms/step

# %%
# inversing Normalization/scaling
upcoming_prediction[['open','close']] = MMS.inverse_transform(upcoming_prediction[['open','close']])

# %%
# plotting Upcoming Open price on date index
fig,ax=plt.subplots(figsize=(10,5))
ax.plot(df_merge.loc['2021-04-01':,'open'],label='Current Open Price')
ax.plot(upcoming_prediction.loc['2021-04-01':,'open'],label='Upcoming Open Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('Upcoming Open price prediction',size=15)
ax.legend()
fig.show()

# %%
# plotting Upcoming Close price on date index
fig,ax=plt.subplots(figsize=(10,5))
ax.plot(df_merge.loc['2021-04-01':,'close'],label='Current close Price')
ax.plot(upcoming_prediction.loc['2021-04-01':,'close'],label='Upcoming close Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('Upcoming close price prediction',size=15)
ax.legend()
fig.show()
